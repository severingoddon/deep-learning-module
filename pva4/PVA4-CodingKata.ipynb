# %% [markdown]
# ## PVA 4 - Coding Kata
#
# Arbeitet in Zweier-Teams an folgenden Aufgaben! Aber bitte **jedes Teammitglied** gibt Notebook im Moodle ab.

# %% [markdown]
# **Aufgabe 1**
#
# Verwenden sie die Testbilder im Google-Drive PVA4. Wenden Sie Transfer Learning mit Keras an und vergleiche die Ergebnisse der folgenden vortrainierten Netze:
# - VGG16
# - VGG19
# - ResNet50
# - InceptionV3
# - MobileNetV2
#
# _Erstelle eine Matrix (Bilder/Netze) mit den Top-1 Ergebnissen._

# %% [markdown]
# **Aufgabe 2**
#
# 1. Rotiere die Bilder um 10, 20 Grad (nach links oder rechts) und vergleiche die Ergebnisse der obigen vortrainierten Netze
# 2. Rotiere die Bilder um 90 bzw. 180 Grad und vergleiche die Ergebnisse die Ergebnisse der obigen vortrainierten Netze

# %% [markdown]
# **Aufgabe 3**
#
# 1. Teste folgendes Google Colab Notebook zu [Image Captioning](https://colab.research.google.com/github/Hvass-Labs/TensorFlow-Tutorials/blob/master/22_Image_Captioning.ipynb)
# 2. Dieses Notebook verwendet VGG16 - tausche aus gegen ein beliebiges anderes vortrainiertes Netz (das Keras zur Verfügung stellt). Welche Änderungen sind notwendig?
